# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
import tensorflow as tf
import tensorflow.keras.callbacks

# %%
df = pd.read_csv("train.csv")
df = df.drop(["ID", "Levy"], axis=1)
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(axis=0)

# %%
label_encoder = LabelEncoder()
minmax_scaler = MinMaxScaler()

# %%
df
# Out:
#        Price   Manufacturer    Model  Prod. year   Category Leather interior  \
# 0      13328          LEXUS   RX 450        2010       Jeep              Yes
# 1      16621      CHEVROLET  Equinox        2011       Jeep               No
# 2       8467          HONDA      FIT        2006  Hatchback               No
# 3       3607           FORD   Escape        2011       Jeep              Yes
# 4      11726          HONDA      FIT        2014  Hatchback              Yes
# ...      ...            ...      ...         ...        ...              ...
# 19232   8467  MERCEDES-BENZ  CLK 200        1999      Coupe              Yes
# 19233  15681        HYUNDAI   Sonata        2011      Sedan              Yes
# 19234  26108        HYUNDAI   Tucson        2010       Jeep              Yes
# 19235   5331      CHEVROLET  Captiva        2007       Jeep              Yes
# 19236    470        HYUNDAI   Sonata        2012      Sedan              Yes
#
#       Fuel type Engine volume    Mileage  Cylinders Gear box type  \
# 0        Hybrid           3.5  186005 km        6.0     Automatic
# 1        Petrol             3  192000 km        6.0     Tiptronic
# 2        Petrol           1.3  200000 km        4.0      Variator
# 3        Hybrid           2.5  168966 km        4.0     Automatic
# 4        Petrol           1.3   91901 km        4.0     Automatic
# ...         ...           ...        ...        ...           ...
# 19232       CNG     2.0 Turbo  300000 km        4.0        Manual
# 19233    Petrol           2.4  161600 km        4.0     Tiptronic
# 19234    Diesel             2  116365 km        4.0     Automatic
# 19235    Diesel             2   51258 km        4.0     Automatic
# 19236    Hybrid           2.4  186923 km        4.0     Automatic
#
#       Drive wheels   Doors             Wheel   Color  Airbags
# 0              4x4  04-May        Left wheel  Silver       12
# 1              4x4  04-May        Left wheel   Black        8
# 2            Front  04-May  Right-hand drive   Black        2
# 3              4x4  04-May        Left wheel   White        0
# 4            Front  04-May        Left wheel  Silver        4
# ...            ...     ...               ...     ...      ...
# 19232         Rear  02-Mar        Left wheel  Silver        5
# 19233        Front  04-May        Left wheel     Red        8
# 19234        Front  04-May        Left wheel    Grey        4
# 19235        Front  04-May        Left wheel   Black        4
# 19236        Front  04-May        Left wheel   White       12
#
# [19237 rows x 16 columns]

# %%
def process_airbags_cylinders(x):
    if (x>=0 and x<=4):
        return 0
    elif (x>4 and x<=8):
        return 1
    elif (x>8 and x<=12):
        return 2
    elif (x>12 and x<=16):
        return 3
df["Airbags"] = df["Airbags"].apply(process_airbags_cylinders)
df["Cylinders"] = df["Cylinders"].apply(process_airbags_cylinders)

# %%
df["Color"] = label_encoder.fit_transform(df["Color"])

# %%
df["Wheel"] = label_encoder.fit_transform(df["Wheel"])

# %%
df["Doors"] = label_encoder.fit_transform(df["Doors"])

# %%
df["Drive wheels"] = label_encoder.fit_transform(df["Drive wheels"])

# %%
df["Gear box type"] = label_encoder.fit_transform(df["Gear box type"])

# %%
df["Fuel type"] = label_encoder.fit_transform(df["Fuel type"])

# %%
df["Leather interior"] = label_encoder.fit_transform(df["Leather interior"])

# %%
def process_milage(x):
    x = float("".join([i for i in x if i.isdigit() or i == "."]))
    x = np.log10(x)
    return x

df["Mileage"] = df["Mileage"].apply(process_milage)

# %%
def process_turbo(x):
    if "Turbo" in x:
        return 1
    else:
        return 0
df["Turbo"] = df["Engine volume"].apply(process_turbo)

# %%
def process_engine_volume(x):
    x = float("".join([i for i in x if i.isdigit() or i == "."]))
    if x <= 3:
        return 0
    else:
        return 1
df["Engine volume"] = df["Engine volume"].apply(process_engine_volume)

# %%
def process_prodyear(x):
    if x <= 1950:
        return 0
    elif 1951 < x <= 1975:
        return 1
    elif 1976 < x <= 2000:
        return 2
    elif 2001 < x <= 2010:        
        return 3
    elif 2011 < x <= 2015:
        return 4
    else:
        return 5

df["Prod. year"] = df["Prod. year"].apply(process_prodyear)

# %%
def process_price(x):
    return np.log10(x)

df["Price"] = df["Price"].apply(process_price)

# %%
for col in ["Model", "Manufacturer", "Category"]:
    x = label_encoder.fit_transform(df[col])
    x = minmax_scaler.fit_transform(x.reshape(-1, 1))
    df[col] = x

# %%
df
# Out:
#           Price  Manufacturer     Model  Prod. year  Category  \
# 0      4.124765      0.500000  0.781624           3       0.4
# 1      4.220657      0.125000  0.414097           5       0.4
# 2      3.927730      0.328125  0.430459           3       0.3
# 3      3.557146      0.250000  0.415985           5       0.4
# 4      4.069150      0.328125  0.430459           4       0.3
# ...         ...           ...       ...         ...       ...
# 19232  3.927730      0.562500  0.242291           2       0.1
# 19233  4.195374      0.359375  0.839522           5       0.9
# 19234  4.416774      0.359375  0.907489           3       0.4
# 19235  3.726809      0.125000  0.286973           3       0.4
# 19236  2.672098      0.359375  0.839522           4       0.9
#
#        Leather interior  Fuel type  Engine volume   Mileage  Cylinders  \
# 0                     1          2              1  5.269525          1
# 1                     0          5              0  5.283301          1
# 2                     0          5              0  5.301030          0
# 3                     1          2              0  5.227799          0
# 4                     1          5              0  4.963320          0
# ...                 ...        ...            ...       ...        ...
# 19232                 1          0              0  5.477121          0
# 19233                 1          5              0  5.208441          0
# 19234                 1          1              0  5.065822          0
# 19235                 1          1              0  4.709762          0
# 19236                 1          2              0  5.271663          0
#
#        Gear box type  Drive wheels  Doors  Wheel  Color  Airbags  Turbo
# 0                  0             0      1      0     12        2      0
# 1                  2             0      1      0      1        1      0
# 2                  3             1      1      1      1        0      0
# 3                  0             0      1      0     14        0      0
# 4                  0             1      1      0     12        0      0
# ...              ...           ...    ...    ...    ...      ...    ...
# 19232              1             2      0      0     12        1      1
# 19233              2             1      1      0     11        1      0
# 19234              0             1      1      0      7        0      0
# 19235              0             1      1      0      1        0      0
# 19236              0             1      1      0     14        2      0
#
# [19237 rows x 17 columns]

# %%
# for col in df.columns:
#     if col in ["Price", "Mileage", "Model", "Manufacturer", "Category"]:
#         pass
#     else:
#         df[col] = minmax_scaler.fit_transform(np.array(df[col]).reshape(-1, 1))

# %%
df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(axis=0)

# %%
x = np.array(df.drop("Price", axis=1))
y = np.array(df["Price"]).reshape(-1, 1)

# %%
x.shape, y.shape
# Out:
# ((18516, 16), (18516, 1))

# %%
def create_batches_x(array, batch_size):
    q, mod = divmod(len(array), batch_size)
    array = array[:-mod]
    array = array.reshape((q, batch_size, 16))
    return array

def create_batches_y(array, batch_size):
    q, mod = divmod(len(array), batch_size)
    array = array[:-mod]
    array = array.reshape((q, batch_size, 1))
    return array
x, y = create_batches_x(x, 32), create_batches_y(y, 32)

# %%
x.shape, y.shape
# Out:
# ((18516, 16), (18516, 1))

# %%
np.save("x.npy", x)
np.save("y.npy", y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
# x_train, x_test, y_train, y_test = torch.Tensor(x_train), torch.Tensor(x_test), torch.Tensor(y_train), torch.Tensor(y_test)

# %%
x_train.shape, y_train.shape
# Out:
# ((14812, 16), (14812, 1))

# %%
count = np.isinf(x_train).sum()
print(count)
# Out:
# 0

# %%
for col in df.columns:
    x = np.array(df[col])
    print(np.isinf(x).sum(), col)
# Out:
# 0 Price
# 0 Manufacturer
# 0 Model
# 0 Prod. year
# 0 Category
# 0 Leather interior
# 0 Fuel type
# 0 Engine volume
# 0 Mileage
# 0 Cylinders
# 0 Gear box type
# 0 Drive wheels
# 0 Doors
# 0 Wheel
# 0 Color
# 0 Airbags
# 0 Turbo

# %%
import tensorflow as tf

# model = tf.keras.Sequential([

#     tf.keras.Input(x_train.shape[1]),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(512,activation='elu'),
#     tf.keras.layers.Dropout(.4),
#     tf.keras.layers.Dense(512, activation='elu'),
#     tf.keras.layers.Dropout(.333),
#     tf.keras.layers.Dense(64, activation='elu'),
#     tf.keras.layers.Dense(1,activation='linear')
# ])

model = tf.keras.Sequential([

    tf.keras.Conv1D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='elu'),
    tf.keras.layers.Dropout(.4),
    tf.keras.layers.Dense(512, activation='elu'),
    tf.keras.layers.Dropout(.333),
    tf.keras.layers.Dense(64, activation='elu'),
    tf.keras.layers.Dense(1,activation='linear')
])

# model.summary()


optim = tf.keras.optimizers.Adam(lr=0.001)
loss = 'mae'
logdir = "runs/tensorflow1/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
# loss = 'mean_absolute_error'
# loss = 'mean_squared_error'


# def sch(epoch, lr):
#     if epoch%5== 0:
#         return lr*.1
#     else:
#         return lr


# cb = [tf.keras.callbacks.LearningRateScheduler(sch,0),

#     tf.keras.callbacks.ReduceLROnPlateau(
#     monitor='val_loss', factor=0.1, patience=5, verbose=1,
#     mode='auto', min_delta=0.0001, cooldown=0, min_lr=0),

#     tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss', min_delta=0, patience=10, verbose=1,
#     mode='auto', baseline=None, restore_best_weights=True
# )

# ]

model.compile(optimizer=optim, loss=loss, metrics=[
              'mean_squared_logarithmic_error'])
history = model.fit(x_train, y_train, epochs=100,verbose=1,validation_split=.1, callbacks=[tensorboard_callback])
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Epoch 1/100
# 417/417 [==============================] - 3s 5ms/step - loss: 0.5477 - mean_squared_logarithmic_error: 0.0367 - val_loss: 0.4322 - val_mean_squared_logarithmic_error: 0.0214
# Epoch 2/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.4415 - mean_squared_logarithmic_error: 0.0243 - val_loss: 0.4177 - val_mean_squared_logarithmic_error: 0.0202
# Epoch 3/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.4172 - mean_squared_logarithmic_error: 0.0229 - val_loss: 0.3771 - val_mean_squared_logarithmic_error: 0.0191
# Epoch 4/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3988 - mean_squared_logarithmic_error: 0.0223 - val_loss: 0.3608 - val_mean_squared_logarithmic_error: 0.0186
# Epoch 5/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3863 - mean_squared_logarithmic_error: 0.0217 - val_loss: 0.3537 - val_mean_squared_logarithmic_error: 0.0190
# Epoch 6/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3844 - mean_squared_logarithmic_error: 0.0216 - val_loss: 0.3508 - val_mean_squared_logarithmic_error: 0.0191
# Epoch 7/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3802 - mean_squared_logarithmic_error: 0.0215 - val_loss: 0.3551 - val_mean_squared_logarithmic_error: 0.0199
# Epoch 8/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3756 - mean_squared_logarithmic_error: 0.0212 - val_loss: 0.3522 - val_mean_squared_logarithmic_error: 0.0199
# Epoch 9/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3738 - mean_squared_logarithmic_error: 0.0212 - val_loss: 0.3503 - val_mean_squared_logarithmic_error: 0.0189
# Epoch 10/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3703 - mean_squared_logarithmic_error: 0.0210 - val_loss: 0.3525 - val_mean_squared_logarithmic_error: 0.0183
# Epoch 11/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3703 - mean_squared_logarithmic_error: 0.0209 - val_loss: 0.3454 - val_mean_squared_logarithmic_error: 0.0190
# Epoch 12/100
# 417/417 [==============================] - 3s 6ms/step - loss: 0.3671 - mean_squared_logarithmic_error: 0.0208 - val_loss: 0.3475 - val_mean_squared_logarithmic_error: 0.0189
# Epoch 13/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3670 - mean_squared_logarithmic_error: 0.0206 - val_loss: 0.3441 - val_mean_squared_logarithmic_error: 0.0183
# Epoch 14/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3667 - mean_squared_logarithmic_error: 0.0206 - val_loss: 0.3496 - val_mean_squared_logarithmic_error: 0.0180
# Epoch 15/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3666 - mean_squared_logarithmic_error: 0.0205 - val_loss: 0.3598 - val_mean_squared_logarithmic_error: 0.0177
# Epoch 16/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3633 - mean_squared_logarithmic_error: 0.0204 - val_loss: 0.3457 - val_mean_squared_logarithmic_error: 0.0186
# Epoch 17/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3619 - mean_squared_logarithmic_error: 0.0201 - val_loss: 0.3386 - val_mean_squared_logarithmic_error: 0.0183
# Epoch 18/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3623 - mean_squared_logarithmic_error: 0.0201 - val_loss: 0.3347 - val_mean_squared_logarithmic_error: 0.0175
# Epoch 19/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3581 - mean_squared_logarithmic_error: 0.0198 - val_loss: 0.3336 - val_mean_squared_logarithmic_error: 0.0178
# Epoch 20/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3575 - mean_squared_logarithmic_error: 0.0197 - val_loss: 0.3376 - val_mean_squared_logarithmic_error: 0.0183
# Epoch 21/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3593 - mean_squared_logarithmic_error: 0.0198 - val_loss: 0.3498 - val_mean_squared_logarithmic_error: 0.0207
# Epoch 22/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3539 - mean_squared_logarithmic_error: 0.0194 - val_loss: 0.3306 - val_mean_squared_logarithmic_error: 0.0176
# Epoch 23/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3501 - mean_squared_logarithmic_error: 0.0194 - val_loss: 0.3320 - val_mean_squared_logarithmic_error: 0.0176
# Epoch 24/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3499 - mean_squared_logarithmic_error: 0.0192 - val_loss: 0.3498 - val_mean_squared_logarithmic_error: 0.0191
# Epoch 25/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3501 - mean_squared_logarithmic_error: 0.0191 - val_loss: 0.3273 - val_mean_squared_logarithmic_error: 0.0172
# Epoch 26/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3474 - mean_squared_logarithmic_error: 0.0192 - val_loss: 0.3228 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 27/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3463 - mean_squared_logarithmic_error: 0.0190 - val_loss: 0.3309 - val_mean_squared_logarithmic_error: 0.0181
# Epoch 28/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3453 - mean_squared_logarithmic_error: 0.0189 - val_loss: 0.3397 - val_mean_squared_logarithmic_error: 0.0169
# Epoch 29/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3429 - mean_squared_logarithmic_error: 0.0188 - val_loss: 0.3802 - val_mean_squared_logarithmic_error: 0.0202
# Epoch 30/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3459 - mean_squared_logarithmic_error: 0.0190 - val_loss: 0.3230 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 31/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3445 - mean_squared_logarithmic_error: 0.0188 - val_loss: 0.3254 - val_mean_squared_logarithmic_error: 0.0167
# Epoch 32/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3481 - mean_squared_logarithmic_error: 0.0192 - val_loss: 0.3335 - val_mean_squared_logarithmic_error: 0.0169
# Epoch 33/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3463 - mean_squared_logarithmic_error: 0.0190 - val_loss: 0.3310 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 34/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3431 - mean_squared_logarithmic_error: 0.0188 - val_loss: 0.3209 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 35/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3382 - mean_squared_logarithmic_error: 0.0185 - val_loss: 0.3230 - val_mean_squared_logarithmic_error: 0.0174
# Epoch 36/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3430 - mean_squared_logarithmic_error: 0.0187 - val_loss: 0.3152 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 37/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3399 - mean_squared_logarithmic_error: 0.0186 - val_loss: 0.3160 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 38/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3394 - mean_squared_logarithmic_error: 0.0186 - val_loss: 0.3222 - val_mean_squared_logarithmic_error: 0.0172
# Epoch 39/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3388 - mean_squared_logarithmic_error: 0.0185 - val_loss: 0.3163 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 40/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3375 - mean_squared_logarithmic_error: 0.0185 - val_loss: 0.3152 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 41/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3359 - mean_squared_logarithmic_error: 0.0184 - val_loss: 0.3237 - val_mean_squared_logarithmic_error: 0.0175
# Epoch 42/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3372 - mean_squared_logarithmic_error: 0.0184 - val_loss: 0.3622 - val_mean_squared_logarithmic_error: 0.0188
# Epoch 43/100
# 417/417 [==============================] - 3s 6ms/step - loss: 0.3348 - mean_squared_logarithmic_error: 0.0184 - val_loss: 0.3212 - val_mean_squared_logarithmic_error: 0.0169
# Epoch 44/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3347 - mean_squared_logarithmic_error: 0.0183 - val_loss: 0.3167 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 45/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3348 - mean_squared_logarithmic_error: 0.0184 - val_loss: 0.3179 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 46/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3325 - mean_squared_logarithmic_error: 0.0180 - val_loss: 0.3162 - val_mean_squared_logarithmic_error: 0.0171
# Epoch 47/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3364 - mean_squared_logarithmic_error: 0.0186 - val_loss: 0.3150 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 48/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3331 - mean_squared_logarithmic_error: 0.0183 - val_loss: 0.3158 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 49/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3330 - mean_squared_logarithmic_error: 0.0181 - val_loss: 0.3179 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 50/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3321 - mean_squared_logarithmic_error: 0.0183 - val_loss: 0.3117 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 51/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3354 - mean_squared_logarithmic_error: 0.0185 - val_loss: 0.3124 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 52/100
# 417/417 [==============================] - 2s 6ms/step - loss: 0.3315 - mean_squared_logarithmic_error: 0.0182 - val_loss: 0.3174 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 53/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3297 - mean_squared_logarithmic_error: 0.0180 - val_loss: 0.3184 - val_mean_squared_logarithmic_error: 0.0168
# Epoch 54/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3314 - mean_squared_logarithmic_error: 0.0181 - val_loss: 0.3151 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 55/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3308 - mean_squared_logarithmic_error: 0.0181 - val_loss: 0.3212 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 56/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3304 - mean_squared_logarithmic_error: 0.0179 - val_loss: 0.3128 - val_mean_squared_logarithmic_error: 0.0168
# Epoch 57/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3297 - mean_squared_logarithmic_error: 0.0181 - val_loss: 0.3098 - val_mean_squared_logarithmic_error: 0.0159
# Epoch 58/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3295 - mean_squared_logarithmic_error: 0.0178 - val_loss: 0.3227 - val_mean_squared_logarithmic_error: 0.0167
# Epoch 59/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3297 - mean_squared_logarithmic_error: 0.0179 - val_loss: 0.3296 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 60/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3293 - mean_squared_logarithmic_error: 0.0179 - val_loss: 0.3226 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 61/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3282 - mean_squared_logarithmic_error: 0.0180 - val_loss: 0.3160 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 62/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3267 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3069 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 63/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3290 - mean_squared_logarithmic_error: 0.0181 - val_loss: 0.3132 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 64/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3259 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3177 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 65/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3266 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3145 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 66/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3262 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3104 - val_mean_squared_logarithmic_error: 0.0168
# Epoch 67/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3244 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3105 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 68/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3256 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3128 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 69/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3241 - mean_squared_logarithmic_error: 0.0176 - val_loss: 0.3182 - val_mean_squared_logarithmic_error: 0.0170
# Epoch 70/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3235 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3117 - val_mean_squared_logarithmic_error: 0.0163
# Epoch 71/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3266 - mean_squared_logarithmic_error: 0.0178 - val_loss: 0.3068 - val_mean_squared_logarithmic_error: 0.0161
# Epoch 72/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3244 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3058 - val_mean_squared_logarithmic_error: 0.0160
# Epoch 73/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3251 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3121 - val_mean_squared_logarithmic_error: 0.0172
# Epoch 74/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3214 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3091 - val_mean_squared_logarithmic_error: 0.0158
# Epoch 75/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3236 - mean_squared_logarithmic_error: 0.0178 - val_loss: 0.3222 - val_mean_squared_logarithmic_error: 0.0162
# Epoch 76/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3240 - mean_squared_logarithmic_error: 0.0176 - val_loss: 0.3052 - val_mean_squared_logarithmic_error: 0.0159
# Epoch 77/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3219 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3116 - val_mean_squared_logarithmic_error: 0.0159
# Epoch 78/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3224 - mean_squared_logarithmic_error: 0.0176 - val_loss: 0.3151 - val_mean_squared_logarithmic_error: 0.0167
# Epoch 79/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3204 - mean_squared_logarithmic_error: 0.0173 - val_loss: 0.3117 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 80/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3223 - mean_squared_logarithmic_error: 0.0177 - val_loss: 0.3056 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 81/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3215 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3092 - val_mean_squared_logarithmic_error: 0.0157
# Epoch 82/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3226 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3111 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 83/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3200 - mean_squared_logarithmic_error: 0.0173 - val_loss: 0.3204 - val_mean_squared_logarithmic_error: 0.0165
# Epoch 84/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3181 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3033 - val_mean_squared_logarithmic_error: 0.0161
# Epoch 85/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3173 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3161 - val_mean_squared_logarithmic_error: 0.0173
# Epoch 86/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3186 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3067 - val_mean_squared_logarithmic_error: 0.0160
# Epoch 87/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3205 - mean_squared_logarithmic_error: 0.0175 - val_loss: 0.3115 - val_mean_squared_logarithmic_error: 0.0166
# Epoch 88/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3203 - mean_squared_logarithmic_error: 0.0176 - val_loss: 0.3174 - val_mean_squared_logarithmic_error: 0.0170
# Epoch 89/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3190 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3117 - val_mean_squared_logarithmic_error: 0.0167
# Epoch 90/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3187 - mean_squared_logarithmic_error: 0.0176 - val_loss: 0.3088 - val_mean_squared_logarithmic_error: 0.0164
# Epoch 91/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3161 - mean_squared_logarithmic_error: 0.0173 - val_loss: 0.3110 - val_mean_squared_logarithmic_error: 0.0171
# Epoch 92/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3169 - mean_squared_logarithmic_error: 0.0172 - val_loss: 0.3110 - val_mean_squared_logarithmic_error: 0.0170
# Epoch 93/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3165 - mean_squared_logarithmic_error: 0.0172 - val_loss: 0.3088 - val_mean_squared_logarithmic_error: 0.0169
# Epoch 94/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3184 - mean_squared_logarithmic_error: 0.0174 - val_loss: 0.3146 - val_mean_squared_logarithmic_error: 0.0169
# Epoch 95/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3159 - mean_squared_logarithmic_error: 0.0172 - val_loss: 0.3070 - val_mean_squared_logarithmic_error: 0.0167
# Epoch 96/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3150 - mean_squared_logarithmic_error: 0.0173 - val_loss: 0.3012 - val_mean_squared_logarithmic_error: 0.0159
# Epoch 97/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3136 - mean_squared_logarithmic_error: 0.0171 - val_loss: 0.3105 - val_mean_squared_logarithmic_error: 0.0171
# Epoch 98/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3132 - mean_squared_logarithmic_error: 0.0171 - val_loss: 0.2972 - val_mean_squared_logarithmic_error: 0.0157
# Epoch 99/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3163 - mean_squared_logarithmic_error: 0.0173 - val_loss: 0.3032 - val_mean_squared_logarithmic_error: 0.0160
# Epoch 100/100
# 417/417 [==============================] - 2s 5ms/step - loss: 0.3156 - mean_squared_logarithmic_error: 0.0172 - val_loss: 0.3092 - val_mean_squared_logarithmic_error: 0.0161
