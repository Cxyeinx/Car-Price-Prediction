# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df = df.drop(["ID", "Levy", "Model", "Drive wheels", "Doors", "Wheel"], axis=1)

# %%
df
# Out:
#        Price   Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0      13328          LEXUS        2010       Jeep              Yes    Hybrid
# 1      16621      CHEVROLET        2011       Jeep               No    Petrol
# 2       8467          HONDA        2006  Hatchback               No    Petrol
# 3       3607           FORD        2011       Jeep              Yes    Hybrid
# 4      11726          HONDA        2014  Hatchback              Yes    Petrol
# ...      ...            ...         ...        ...              ...       ...
# 19232   8467  MERCEDES-BENZ        1999      Coupe              Yes       CNG
# 19233  15681        HYUNDAI        2011      Sedan              Yes    Petrol
# 19234  26108        HYUNDAI        2010       Jeep              Yes    Diesel
# 19235   5331      CHEVROLET        2007       Jeep              Yes    Diesel
# 19236    470        HYUNDAI        2012      Sedan              Yes    Hybrid
#
# ...

# %%
one_hot_encoding = ["Manufacturer", "Category", "Leather interior", "Fuel type", "Gear box type", "Color"]
scaling = ["Prod. year", "Engine volume", "Mileage", "Airbags"]

# %%
def process_engine_volume(x):
    x = float("".join([i for i in x if i.isdigit() or i == "."]))
    return x

df["Engine volume"] = df["Engine volume"].apply(process_engine_volume)

# %%
def process_mileage(x):
    x = float("".join([i for i in x if i.isdigit() or i == "."]))
    x = 10000 * round(x/10000)
    return x

df["Mileage"] = df["Mileage"].apply(process_mileage)

# %%
ohe_scaler = LabelEncoder()
minmax_scaler = MinMaxScaler()

# %%
for col in one_hot_encoding:
    df[col] = ohe_scaler.fit_transform(df[col])
    df[col] = minmax_scaler.fit_transform(np.array(df[col]).reshape(-1, 1))

# %%
df
# Out:
#        Price  Manufacturer  Prod. year  Category  Leather interior  Fuel type  \
# 0      13328      0.500000        2010       0.4               1.0   0.333333
# 1      16621      0.125000        2011       0.4               0.0   0.833333
# 2       8467      0.328125        2006       0.3               0.0   0.833333
# 3       3607      0.250000        2011       0.4               1.0   0.333333
# 4      11726      0.328125        2014       0.3               1.0   0.833333
# ...      ...           ...         ...       ...               ...        ...
# 19232   8467      0.562500        1999       0.1               1.0   0.000000
# 19233  15681      0.359375        2011       0.9               1.0   0.833333
# 19234  26108      0.359375        2010       0.4               1.0   0.166667
# 19235   5331      0.125000        2007       0.4               1.0   0.166667
# 19236    470      0.359375        2012       0.9               1.0   0.333333
#
# ...

# %%
for col in scaling:
    df[col] = minmax_scaler.fit_transform(np.array(df[col]).reshape(-1, 1))

# %%
df
# Out:
#        Price  Manufacturer  Prod. year  Category  Leather interior  Fuel type  \
# 0      13328      0.500000    0.876543       0.4               1.0   0.333333
# 1      16621      0.125000    0.888889       0.4               0.0   0.833333
# 2       8467      0.328125    0.827160       0.3               0.0   0.833333
# 3       3607      0.250000    0.888889       0.4               1.0   0.333333
# 4      11726      0.328125    0.925926       0.3               1.0   0.833333
# ...      ...           ...         ...       ...               ...        ...
# 19232   8467      0.562500    0.740741       0.1               1.0   0.000000
# 19233  15681      0.359375    0.888889       0.9               1.0   0.833333
# 19234  26108      0.359375    0.876543       0.4               1.0   0.166667
# 19235   5331      0.125000    0.839506       0.4               1.0   0.166667
# 19236    470      0.359375    0.901235       0.9               1.0   0.333333
#
# ...

# %%
def process_price(x):
#     x = float("".join([i for i in x if i.isdigit() or i == "."]))
    x = 1000 * round(x/1000)

    return x

df["Price"] = df["Price"].apply(process_price)

# %%
df
# Out:
#        Price  Manufacturer  Prod. year  Category  Leather interior  Fuel type  \
# 0      13000      0.500000    0.876543       0.4               1.0   0.333333
# 1      17000      0.125000    0.888889       0.4               0.0   0.833333
# 2       8000      0.328125    0.827160       0.3               0.0   0.833333
# 3       4000      0.250000    0.888889       0.4               1.0   0.333333
# 4      12000      0.328125    0.925926       0.3               1.0   0.833333
# ...      ...           ...         ...       ...               ...        ...
# 19232   8000      0.562500    0.740741       0.1               1.0   0.000000
# 19233  16000      0.359375    0.888889       0.9               1.0   0.833333
# 19234  26000      0.359375    0.876543       0.4               1.0   0.166667
# 19235   5000      0.125000    0.839506       0.4               1.0   0.166667
# 19236      0      0.359375    0.901235       0.9               1.0   0.333333
#
# ...

# %%
x = np.array(df.drop("Price", axis=1))[:-5].reshape(19232//32, 32, 11)
y = np.array(df["Price"]).reshape(-1, 1)[:-5].reshape(19232//32, 32, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train, x_test, y_train, y_test = torch.Tensor(x_train), torch.Tensor(x_test), torch.Tensor(y_train), torch.Tensor(y_test)

# %%
print(x_train.shape, y_train.shape)
# Out:
# torch.Size([480, 32, 11]) torch.Size([480, 32, 1])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class DNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.block = nn.Sequential(
            nn.Linear(11, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
#             nn.Sigmoid()
                                   )
    def forward(self, x):
        return self.block(x)


loss_function = nn.L1Loss()
net = DNN()
optimizer = optim.Adam(net.parameters(), lr=0.001)


for epoch in range(10_000):
    for xx, yy in zip(x_train, y_train):
        outputs = net(xx)
        loss = loss_function(outputs, yy)
        net.zero_grad()
        loss.backward()
        optimizer.step()
    
    if epoch % 1000:
        with torch.no_grad():
            output = net(x_test)
            l = loss_function(output, y_test)
        print(f"training loss: {loss}, testing loss: {l}")
# Out:
# training loss: 13077.2626953125, testing loss: 11393.0390625
# training loss: 12861.14453125, testing loss: 11256.1318359375
# training loss: 12703.580078125, testing loss: 11068.677734375
# training loss: 12154.99609375, testing loss: 10746.0224609375
# training loss: 11618.7744140625, testing loss: 10263.5107421875
# training loss: 11406.7724609375, testing loss: 9832.7890625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-83384c7d39f4> in <module>
#      29 for epoch in range(10_000):
#      30     for xx, yy in zip(x_train, y_train):
# ---> 31         outputs = net(xx)
#      32         loss = loss_function(outputs, yy)
#      33         net.zero_grad()
#
# ~/anaconda3/envs/myenv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
# ...
